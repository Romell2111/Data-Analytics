# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
# %matplotlib inline

# %%
#Creates new dataframe from csv file on Desktop

complaints = pd.read_csv('/Users/rng/Desktop/complaints.csv') #Use this file path if Mac and 'C:\\Users\\rng\\Desktop\\emails.csv' if Windows'
#Syntax: dataframe = pd.read_csv(file_path)

# %%
#Show top 5 rows of dataframe ([-X:] for last X rows in dataframe)
complaints[:5]
#Syntax: dataframe[:X]
# Out:
#    complaint_id date_received year_month                   issue state
# 0          9027    2012-01-01    2012-01  Technical Difficulties    TN
# 1          9022    2012-01-01    2012-01  Technical Difficulties    CA
# 2          9003    2012-01-01    2012-01  Technical Difficulties    WA
# 3          9031    2012-01-01    2012-01  Technical Difficulties    CT
# 4          9012    2012-01-01    2012-01  Technical Difficulties    FL

# %%
#Aggregate data by issue

complaints_by_issue = complaints.groupby(by='issue')['complaint_id'].count().reset_index().sort_values(by='complaint_id',ascending=False)
complaints_by_issue 
#Syntax: agg_data = dataframe.groupby(by='aggregator')['agg_metric].agg_method.reset_index()
# Out:
#                         issue  complaint_id
# 3      Technical Difficulties        215572
# 0  Missing/Incorrect Delivery        146562
# 2         Product Malfunction        130457
# 1      Online Checkout Issues         79250

# %%
#Aggregate data over time

complaints_by_month = complaints.groupby(by='year_month')['complaint_id'].count().reset_index()
complaints_by_month.set_index(['year_month'],inplace=True) #Redefines index values

#Generate line graph with data
graph = complaints_by_month.plot(kind='line',color='green',grid=True,figsize=(10,6)) #Defines graph function
graph.set_facecolor('none') #Set background to transparent
graph.set_ylabel('# of Inquiries',color='white') #Sets y axis to 'Frequency' and label color white
graph.set_xlabel('Date',color='white') #Sets x axis to 'Date' and label color white
graph.tick_params(colors='white')  #Sets font color to white

# %%
#Aggregate data over time by issue
complaints_by_month_by_issue = complaints.groupby(by=['year_month','issue'])['complaint_id'].count().unstack().reset_index()
complaints_by_month_by_issue.set_index(['year_month'],inplace=True) #Redefines index values

#Generate line graph with data
graph = complaints_by_month_by_issue.plot(kind='line',grid=True,figsize=(10,6))
graph.set_facecolor('none') #Set background to transparent
graph.set_ylabel('# of Inquiries',color='white') #Sets y axis to 'Frequency' and label color white
graph.set_xlabel('Date',color='white') #Sets x axis to 'Date' and label color white
graph.tick_params(colors='white')  #Sets font color to white

# %%
#Create Conditional Field from Existing Field
complaints['online_fix'] = np.where((complaints['issue'] == 'Technical Difficulties')
                                   |(complaints['issue'] == 'Online Checkout Issues'),
                                    True, False)        
#Syntax: new_field = np.where(logical_argument,value_if_true,value_if_false)

# %%
#Aggregate data by type
complaints_by_type = complaints.groupby(['year_month','online_fix'])['complaint_id'].count().unstack().reset_index()
complaints_by_type.set_index(['year_month'],inplace=True) #Redefines index values

#Generate line graph with data
graph = complaints_by_type.plot(kind='line',grid=True,figsize=(10,6))
graph.set_facecolor('none') #Set background to transparent
graph.set_ylabel('# of Inquiries',color='white') #Sets y axis to 'Frequency' and label color white
graph.set_xlabel('Date',color='white') #Sets x axis to 'Date' and label color white
graph.tick_params(colors='white')  #Sets font color to white

# %%
#Create new dataframe from filter
complaints_md = complaints[complaints.issue == 'Missing/Incorrect Delivery']
#Syntax: filtered_dataframe = dataframe[logical_argument]

#Aggregate Data over Time by State
complaints_md_by_state = complaints_md.groupby(by=['state'])['complaint_id'].count().reset_index().sort_values(by='complaint_id',ascending=False)
complaints_md_by_state.columns = ['state','inquiry_count'] #Renames columns
complaints_md_by_state[:5]
# Out:
#    state  inquiry_count
# 8     CA          18548
# 53    TX          15663
# 13    FL          13960
# 42    NY           9928
# 15    GA           7236

# %%
#Create new dataframe from filter - loc alternative
complaints_top_states = complaints_md.loc[complaints_md['state'].isin(['CA','TX','FL','NY','GA'])]
#Syntax: filtered_dataframe = dataframe.loc[dataframe['field'].isin([array_of_values])]

#Aggregate/pivot data over time by state
complaints_top_states_agg = complaints_top_states.groupby(by=['year_month','state'])['complaint_id'].count().unstack().reset_index()
complaints_top_states_agg.set_index(['year_month'],inplace=True) #Redefines index values

graph = complaints_top_states_agg.plot(kind='line',grid=True,figsize=(10,6))
graph.set_facecolor('none') #Set background to transparent
graph.set_ylabel('# of Inquiries',color='white') #Sets y axis to 'Frequency' and label color white
graph.set_xlabel('Date',color='white') #Sets x axis to 'Date' and label color white
graph.tick_params(colors='white')  #Sets font color to white

# %%
#Read State Lookup File
state_lookup = pd.read_csv('/Users/rng/Desktop/state_lookup.csv')

complaints_merged = pd.merge(complaints,state_lookup,on='state',how='left')
#Syntax: pd.merge(dataframe_1, dataframe_2, on='common_field',how='merge_type')

# %%
complaints_merged
# Out:
#         complaint_id date_received year_month                       issue  \
# 0               9027    2012-01-01    2012-01      Technical Difficulties
# 1               9022    2012-01-01    2012-01      Technical Difficulties
# 2               9003    2012-01-01    2012-01      Technical Difficulties
# 3               9031    2012-01-01    2012-01      Technical Difficulties
# 4               9012    2012-01-01    2012-01      Technical Difficulties
# 5               9030    2012-01-01    2012-01      Technical Difficulties
# 6               9020    2012-01-01    2012-01      Technical Difficulties
# 7               9014    2012-01-01    2012-01      Technical Difficulties
# 8               9010    2012-01-01    2012-01      Technical Difficulties
# 9               9011    2012-01-01    2012-01      Technical Difficulties
# 10              9024    2012-01-01    2012-01      Technical Difficulties
# 11            219470    2013-01-01    2013-01      Technical Difficulties
# 12            219472    2013-01-01    2013-01      Online Checkout Issues
# 13            219474    2013-01-01    2013-01      Online Checkout Issues
# 14            219497    2013-01-01    2013-01  Missing/Incorrect Delivery
# 15            216003    2013-01-01    2013-01  Missing/Incorrect Delivery
# 16            219453    2013-01-01    2013-01      Technical Difficulties
# 17            219448    2013-01-01    2013-01      Technical Difficulties
# 18            219519    2013-01-01    2013-01      Technical Difficulties
# 19            219511    2013-01-01    2013-01      Online Checkout Issues
# 20            219489    2013-01-01    2013-01      Technical Difficulties
# 21            219494    2013-01-01    2013-01      Technical Difficulties
# 22            219507    2013-01-01    2013-01      Online Checkout Issues
# 23            219522    2013-01-01    2013-01  Missing/Incorrect Delivery
# 24            219482    2013-01-01    2013-01      Technical Difficulties
# 25            215977    2013-01-01    2013-01  Missing/Incorrect Delivery
# 26            219457    2013-01-01    2013-01      Technical Difficulties
# 27            219504    2013-01-01    2013-01  Missing/Incorrect Delivery
# 28            219479    2013-01-01    2013-01      Technical Difficulties
# 29            219510    2013-01-01    2013-01      Technical Difficulties
# ...              ...           ...        ...                         ...
# 571811       2270542    2016-12-31    2016-12         Product Malfunction
# 571812       2270560    2016-12-31    2016-12      Technical Difficulties
# 571813       2270575    2016-12-31    2016-12      Technical Difficulties
# 571814       2270555    2016-12-31    2016-12      Technical Difficulties
# 571815       2270724    2016-12-31    2016-12      Online Checkout Issues
# 571816       2270717    2016-12-31    2016-12      Technical Difficulties
# 571817       2270758    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571818       2270663    2016-12-31    2016-12      Technical Difficulties
# 571819       2270656    2016-12-31    2016-12      Technical Difficulties
# 571820       2270783    2016-12-31    2016-12      Technical Difficulties
# 571821       2270722    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571822       2270769    2016-12-31    2016-12      Technical Difficulties
# 571823       2270604    2016-12-31    2016-12      Technical Difficulties
# 571824       2269706    2016-12-31    2016-12         Product Malfunction
# 571825       2269548    2016-12-31    2016-12      Technical Difficulties
# 571826       2270754    2016-12-31    2016-12         Product Malfunction
# 571827       2270605    2016-12-31    2016-12      Online Checkout Issues
# 571828       2270626    2016-12-31    2016-12      Technical Difficulties
# 571829       2270627    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571830       2270594    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571831       2269382    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571832       2270651    2016-12-31    2016-12      Technical Difficulties
# 571833       2270581    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571834       2270602    2016-12-31    2016-12         Product Malfunction
# 571835       2270693    2016-12-31    2016-12      Technical Difficulties
# 571836       2269563    2016-12-31    2016-12  Missing/Incorrect Delivery
# 571837       2270614    2016-12-31    2016-12         Product Malfunction
# 571838       2269607    2016-12-31    2016-12      Technical Difficulties
# 571839       2269925    2016-12-31    2016-12      Technical Difficulties
# 571840       2270642    2016-12-31    2016-12         Product Malfunction
#
#        state      state_name
# 0         TN       Tennessee
# 1         CA      California
# 2         WA      Washington
# 3         CT     Connecticut
# 4         FL         Florida
# 5         NJ      New Jersey
# 6         CA      California
# 7         CA      California
# 8         CA      California
# 9         TX           Texas
# 10        NY        New York
# 11        FL         Florida
# 12        OR          Oregon
# 13        CT     Connecticut
# 14        NM      New Mexico
# 15        OH            Ohio
# 16        NJ      New Jersey
# 17        NJ      New Jersey
# 18        FL         Florida
# 19        MN       Minnesota
# 20        NJ      New Jersey
# 21        NJ      New Jersey
# 22        PA    Pennsylvania
# 23        MA   Massachusetts
# 24        WI       Wisconsin
# 25        WA      Washington
# 26        CA      California
# 27        TX           Texas
# 28        PA    Pennsylvania
# 29        UT            Utah
# ...      ...             ...
# 571811    MI        Michigan
# 571812    WY         Wyoming
# 571813    MS     Mississippi
# 571814    PA    Pennsylvania
# 571815    GA         Georgia
# 571816    NJ      New Jersey
# 571817    NY        New York
# 571818    NC  North Carolina
# 571819    CA      California
# 571820    NJ      New Jersey
# 571821    OH            Ohio
# 571822    AL         Alabama
# 571823    NC  North Carolina
# 571824    TX           Texas
# 571825    LA       Louisiana
# 571826    TX           Texas
# 571827    CA      California
# 571828    NJ      New Jersey
# 571829    IL        Illinois
# 571830    CA      California
# 571831    IL        Illinois
# 571832    CA      California
# 571833    FL         Florida
# 571834    TX           Texas
# 571835    TX           Texas
# 571836    NC  North Carolina
# 571837    OH            Ohio
# 571838    TX           Texas
# 571839    CA      California
# 571840    AL         Alabama
#
# [571841 rows x 6 columns]
